# %%
# Nicholas Long / Sourav Dey

import os

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(12,16)})

# %% [markdown]
# # RL Base

# %%
# Plot the RL Base
base_dir = 'results_rl_osm_base'
infile = os.path.join(base_dir, 'rl_osm_base.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Cooling_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['ZN1_Cooling_Rate'],
        ax=ax[1]
    ).set_title('Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    
    fig.savefig(out_image)
# Out:
# /Users/nlong/.pyenv/versions/3.6.5/envs/3.6.5-alfalfa/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Plot the RL Base
base_dir = 'results_rl_osm_pid'
infile = os.path.join(base_dir, 'rl_osm_pid.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'RadTemp2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN2_Cooling_Rate',
        'ZN2_Heating_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    
    fig.savefig(out_image)

# %% [markdown]
# # FMU - P Controller

# %%
base_dir = 'results_rl_fmu_simple_1_zone_heating'
infile = os.path.join(base_dir, 'rl_fmu_simple_1_zone_heating.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Heating_Rate',
    ]
    y3_vars = [
        'u1',
        'u2'
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x=df['timestamp'],
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_ylabel('Signal')
    ax[2].set_xlabel('')
    
    fig.savefig(out_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3057cd103270> in <module>
#       1 base_dir = 'results_rl_fmu_simple_1_zone_heating'
# ----> 2 infile = os.path.join(base_dir, 'rl_fmu_simple_1_zone_heating.csv')
#       3 out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
#       4 if os.path.exists(infile):
#       5     temp_vars = [
#
# NameError: name 'os' is not defined

# %% [markdown]
# # FMU Single Zone VAV Baseline

# %%
# Plot the RL Base
base_dir = 'results_rl_fmu_single_zone_vav_baseline'
infile = os.path.join(base_dir, 'rl_fmu_single_zone_vav_baseline.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T1_Rad',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_xticklabels([])
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Control Signal')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')
    
    fig.savefig(out_image)

# %% [markdown]
# # FMU Single Zone VAV - External Control

# %%
# Plot the RL Base
base_dir = 'results_rl_fmu_single_zone_vav'
infile = os.path.join(base_dir, 'rl_fmu_single_zone_vav.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T1_Rad',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_xticklabels([])
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Rewards')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')
    
    fig.savefig(out_image)

# %% [markdown]
# # FMU with Actor/Critic

# %%
base_dir = 'results_rl_fmu_single_zone_vav_02'
infile = os.path.join(base_dir, 'rl_fmu_single_zone_vav_02.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    ax[1].set_ylabel('Watts')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_xticklabels([])
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Rewards')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')
    
    fig.savefig(out_image)

# %% [markdown]
# # FMU with Actor/Critic w/Tuning

# %%
# infile = os.path.join('results_rl_fmu_single_zone_vav', 'rl_fmu_single_zone_vav.csv')
base_dir = 'results_rl_fmu_single_zone_vav_03'
infile = os.path.join(base_dir, 'rl_fmu_single_zone_vav_03.csv')
out_image = f'{base_dir}/{os.path.splitext(os.path.basename(infile))[0]}.png'
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    ax[1].set_ylabel('Watts')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_xticklabels([])
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Rewards')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')
    
    fig.savefig(out_image)
