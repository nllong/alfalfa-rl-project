# %%
# Nicholas Long / Sourav Dey

import os

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(12,16)})

# %% [markdown]
# # RL Base

# %%
# Plot the RL Base
infile = os.path.join('results_rl_osm_base', 'rl_osm_base.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Cooling_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['ZN1_Cooling_Rate'],
        ax=ax[1]
    ).set_title('Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')

# %%
# Plot the RL Base
infile = os.path.join('results_rl_osm_pid', 'rl_osm_pid.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'RadTemp2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN2_Cooling_Rate',
        'ZN2_Heating_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # FMU - P Controller

# %%
infile = os.path.join('results_rl_fmu_simple_1_zone_heating', 'rl_fmu_simple_1_zone_heating.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Heating_Rate',
    ]
    y3_vars = [
        'u1',
        'u2'
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x=df['timestamp'],
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_ylabel('Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # FMU Single Zone VAV Baseline

# %%
# Plot the RL Base
# infile = os.path.join('results-rl-fmu-single_zone_vav', 'rl-fmu-single_zone_vav.csv')
# infile = os.path.join('results_rl_fmu_single_zone_vav', 'rl_fmu_single_zone_vav.csv')
infile = os.path.join('results_rl_fmu_single_zone_vav_baseline', 'rl_fmu_single_zone_vav_baseline.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T1_Rad',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Control Signal')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')

# %% [markdown]
# # FMU Single Zone VAV - External Control

# %%
# Plot the RL Base
infile = os.path.join('results_rl_fmu_single_zone_vav', 'rl_fmu_single_zone_vav.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T1_Rad',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Control Signal')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')

# %% [markdown]
# # FMU with Actor/Critic

# %%
# infile = os.path.join('results_rl_fmu_single_zone_vav', 'rl_fmu_single_zone_vav.csv')
infile = os.path.join('results_rl_fmu_single_zone_vav_02', 'rl_fmu_single_zone_vav_02.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'HeatingSetpoint',
        'CoolingSetpoint',
        # 'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Control Signal')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b0e49a26c23f> in <module>
#      56     ax[2].set_xlabel('')
#      57     ax[2].set_ylabel('Signal')
# ---> 58     plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
#      59     sns.lineplot(
#      60         x='timestamp',
#
# ~/.pyenv/versions/3.6.5/envs/3.6.5-alfalfa/lib/python3.6/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#      72                     "The following 'value_vars' are not present in"
#      73                     " the DataFrame: {missing}"
# ---> 74                     "".format(missing=list(missing))
#      75                 )
#      76         frame = frame.loc[:, id_vars + value_vars]
#
# KeyError: "The following 'value_vars' are not present in the DataFrame: ['Reward']"
