# %%
# Nicholas Long / Sourav Dey

import os

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(12,8)})

# %% [markdown]
# # OpenStudio - Base

# %%
# Plot the RL Base
infile = os.path.join('results-rl-base', 'rl-base.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Cooling_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['ZN1_Cooling_Rate'],
        ax=ax[1]
    ).set_title('Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # OpenStudio - PID

# %%
# Plot the Openstudio Base PID 
infile = os.path.join('results-rl-base-pid', 'rl-base-pid.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'RadTemp2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN2_Cooling_Rate',
        'ZN2_Heating_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # FMU - P Controller

# %%
infile = os.path.join('results-rl-fmu-base', 'rl-fmu-base.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Heating_Rate',
    ]
    y3_vars = [
        'u1',
        'u2'
        
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x=df['timestamp'],
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[1].set_ylabel('Signal')
    ax[2].set_xlabel('')
