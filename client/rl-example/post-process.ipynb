# %%
# Nicholas Long / Sourav Dey

import os

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(12,16)})

# %% [markdown]
# # RL Base

# %%
# Plot the RL Base
infile = os.path.join('results-rl-base', 'rl-base.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Cooling_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['ZN1_Cooling_Rate'],
        ax=ax[1]
    ).set_title('Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
# Out:
# /Users/nlong/.pyenv/versions/3.6.5/envs/3.6.5-alfalfa/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Plot the RL Base
infile = os.path.join('results-rl-base-pid', 'rl-base-pid.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'T2',
        'RadTemp2',
        'Tsetpoint_cooling',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN2_Cooling_Rate',
        'ZN2_Heating_Rate',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    sns.lineplot(
        x=df['timestamp'],
        y=df['u1'],
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # FMU - P Controller

# %%
infile = os.path.join('results-rl-fmu-simple_1_zone_heating', 'rl-fmu-simple_1_zone_heating.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'Tsetpoint_heating',
    ]
    y2_vars = [
        'ZN1_Heating_Rate',
    ]
    y3_vars = [
        'u1',
        'u2'
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(3,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Heating/Cooling Rate')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Rate (J/s)')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x=df['timestamp'],
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_ylabel('Signal')
    ax[2].set_xlabel('')

# %% [markdown]
# # VAV with FMU

# %%
# Plot the RL Base
infile = os.path.join('results-rl-fmu-single_zone_vav', 'rl-fmu-single_zone_vav.csv')
if os.path.exists(infile):
    temp_vars = [
        'T1',
        'HeatingSetpoint',
        'CoolingSetpoint',
        'Toutdoor',
    ]
    y2_vars = [
        'CoolingPower',
        'HeatingPower',
        'FanPower',
        'PumpPower',
    ]
    y3_vars = [
        'u_FanOverride',
    ]

    df = pd.read_csv(infile)
    df['timestamp']= pd.to_datetime(df['timestamp'])
    
    plt.figure(figsize=(12, 8), dpi=70)
    fig, ax = plt.subplots(4,1)
    
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=temp_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[0]
    ).set_title('Temperatures')
    ax[0].set_xlabel('')
    ax[0].set_ylabel('Temp (degC)')
    ax[0].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y2_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[1]
    ).set_title('Power')
    ax[1].set_xlabel('')
    ax[1].set_ylabel('Watts')
    ax[1].set_xticklabels([])
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=y3_vars)
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[2]
    ).set_title('Control Signal')
    ax[2].set_xlabel('')
    ax[2].set_ylabel('Signal')
    plot_data = pd.melt(df, id_vars=['timestamp'], value_vars=['Reward', 'PPD'])
    sns.lineplot(
        x='timestamp',
        y='value',
        hue='variable',
        data=plot_data,
        ax=ax[3]
    ).set_title('Control Signal')
    date_form = DateFormatter("%m/%d\n %H:%M:%S")
    plt.xticks(rotation=90)
    ax[3].xaxis.set_major_formatter(date_form)
    ax[3].set_ylabel('Rewards')
    ax[3].set_xlabel('')

# %%
print(df.describe())
# Out:
#        Unnamed: 0          T1    Toutdoor  CoolingPower  HeatingPower  \
# count  288.000000  288.000000  288.000000         288.0    288.000000
# mean   143.500000   18.731568  -13.773132           0.0   6826.245538
# std     83.282651    2.575004    4.002711           0.0    678.929257
# min      0.000000   13.113245  -19.418374           0.0      0.000000
# 25%     71.750000   17.043443  -17.775407           0.0   7052.218140
# 50%    143.500000   20.048058  -13.890476           0.0   7070.707071
# 75%    215.250000   20.750654  -11.711787           0.0   7070.707071
# max    287.000000   21.236539   -4.449076           0.0   7070.707071
#
#          FanPower  PumpPower  TotalHVACEnergy  HeatingSetpoint  \
# count  288.000000      288.0     2.880000e+02            288.0
# mean   538.329691        0.0     3.096800e+08             21.0
# std     31.522539        0.0     1.880695e+08              0.0
# min      5.231954        0.0     1.785151e+06             21.0
# 25%    540.187174        0.0     1.446234e+08             21.0
# 50%    540.187174        0.0     3.082934e+08             21.0
# 75%    540.187174        0.0     4.721179e+08             21.0
# max    540.187174        0.0     6.359424e+08             21.0
#
#        CoolingSetpoint  FanControlInput  u_CoolingSetpoint  u_HeatingSetpoint  \
# count            288.0       288.000000              288.0              288.0
# mean              25.0         0.943567               25.0               21.0
# std                0.0         0.043968                0.0                0.0
# min               25.0         0.200000               25.0               21.0
# 25%               25.0         0.946158               25.0               21.0
# 50%               25.0         0.946158               25.0               21.0
# 75%               25.0         0.946158               25.0               21.0
# max               25.0         0.946158               25.0               21.0
#
#        u_FanOverride         PMV         PPD
# count     288.000000  288.000000  288.000000
# mean        0.943567   -0.303146    7.183496
# std         0.043968    0.390203   10.103594
# min         0.200000   -1.331331    0.000000
# 25%         0.946158   -0.628449    0.000000
# 50%         0.946158    0.000000    0.000000
# 75%         0.946158    0.000000   13.288404
# max         0.946158    0.000000   41.890719
